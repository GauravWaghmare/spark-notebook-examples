# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from random import random
from operator import add

from pyspark.sql import SparkSession

spark = SparkSession\
    .builder\
    .appName("PythonPi")\
    .getOrCreate()

# %%
partitions = 500
n = 100000 * partitions

def f(_: int) -> float:
    x = random() * 2 - 1
    y = random() * 2 - 1
    return 1 if x ** 2 + y ** 2 <= 1 else 0

count = spark.sparkContext.parallelize(range(1, n + 1), partitions).map(f).reduce(add)
print("Attempt 1: Pi is roughly %f" % (4.0 * count / n))

# %%
partitions = 1000
n = 100000 * partitions

def f(_: int) -> float:
    x = random() * 2 - 1
    y = random() * 2 - 1
    return 1 if x ** 2 + y ** 2 <= 1 else 0

count = spark.sparkContext.parallelize(range(1, n + 1), partitions).map(f).reduce(add)
print("Attempt 2: Pi is roughly %f" % (4.0 * count / n))

# %%
spark.stop()

# %%
print("Goodbye, World!")
